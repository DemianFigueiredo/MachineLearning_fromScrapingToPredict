# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt

import re

# %%
#extranet_out_2022_set_20222
set22 = '../data/extranet_out_2022_set_20222.csv'
df1 = pd.read_csv(set22)
pd.set_option('display.max_columns', None)

#extranet_nov_2022_out_20222
out22 = '../data/extranet_nov_2022_out_20222.csv'
df2 = pd.read_csv(out22)
pd.set_option('display.max_columns', None)

#extranet_feb_2023_nov_2022
nov22 = '../data/extranet_feb_2023_nov_2022.csv'
df3 = pd.read_csv(nov22)
pd.set_option('display.max_columns', None)

#extranet_may_2023_feb_2023
fev23 = '../data/extranet_may_2023_feb_2023.csv'
df4 = pd.read_csv(fev23)
pd.set_option('display.max_columns', None)

#extranet_sept_2003_may_2032
may23 = '../data/extranet_sept_2003_may_2032.csv'
df5 = pd.read_csv(may23)
pd.set_option('display.max_columns', None)

# %%
print(df1.shape)
df1.head()
# Out:
# (16, 37)
#    Oct 1  2022  Oct 2  2022  Oct 3  2022  Oct 4  2022  Oct 5  2022  \
# 0            8            6            5            2            5
# 1           16            6            7           12           10
# 2      -50.39%       +0.00%      -31.03%      -82.72%      -50.62%
# 3  7 out of 11  3 out of 11  6 out of 11  8 out of 11  8 out of 11
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Oct 6  2022  Oct 7  2022  Oct 8  2022 Sep 10  2022 Sep 11  2022  \
# 0            6           11           12            5            2
# 1           15           28           34           26           12
# 2      -60.33%      -60.89%      -64.71%      -80.49%      -83.16%
# 3  8 out of 11  8 out of 11  8 out of 11  9 out of 11  9 out of 11
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Sep 12  2022 Sep 13  2022 Sep 14  2022 Sep 15  2022 Sep 16  2022  \
# 0            4            6            6            8            6
# ...

# %%
print(df2.shape)
df2.head()
# Out:
# (16, 35)
#    Nov 1  2022  Nov 2  2022  Nov 3  2022  Nov 4  2022  Nov 5  2022  \
# 0            0            0            3            3            3
# 1           19           18           21           30           39
# 2     -100.00%     -100.00%      -85.63%      -89.83%      -92.33%
# 3  9 out of 11  9 out of 11  9 out of 11  9 out of 11  9 out of 11
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Oct 10  2022 Oct 11  2022 Oct 12  2022 Oct 13  2022 Oct 14  2022  \
# 0            1            1            1            2            7
# 1           13           15           16           19           23
# 2      -92.52%      -93.44%      -93.65%      -89.19%      -69.23%
# 3  9 out of 11  9 out of 11  9 out of 11  9 out of 11  9 out of 11
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Oct 15  2022 Oct 16  2022 Oct 17  2022 Oct 18  2022 Oct 19  2022  \
# 0            8            2            3            3            5
# ...

# %%
print(df3.shape)
df3.head()
# Out:
# (16, 107)
#    Dec 1  2022 Dec 10  2022 Dec 11  2022 Dec 12  2022 Dec 13  2022  \
# 0            5            7            1            0            4
# 1           12           24           14           10           15
# 2      -59.60%      -70.83%      -92.59%     -100.00%      -73.83%
# 3  8 out of 11  9 out of 11  9 out of 11  9 out of 11  8 out of 11
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Dec 14  2022 Dec 15  2022 Dec 16  2022 Dec 17  2022 Dec 18  2022  \
# 0            7           10            8            5            2
# 1           15           13           17           22           14
# 2      -54.63%      -23.08%      -53.96%      -77.27%      -85.45%
# 3  7 out of 11  5 out of 11  7 out of 11  9 out of 11  9 out of 11
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Dec 19  2022  Dec 2  2022 Dec 20  2022 Dec 21  2022 Dec 22  2022  \
# 0            1            7            3            0            1
# ...

# %%
print(df4.shape)
df4.head()
# Out:
# (16, 107)
#    Apr 1  2023 Apr 10  2023 Apr 11  2023 Apr 12  2023 Apr 13  2023  \
# 0            4            1            4            5            6
# 1           33           11           12           18           23
# 2      -87.97%      -90.80%      -65.22%      -71.43%      -73.77%
# 3  9 out of 11  8 out of 11  7 out of 11  9 out of 11  9 out of 11
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Apr 14  2023 Apr 15  2023 Apr 16  2023 Apr 17  2023 Apr 18  2023  \
# 0            3            2            2            1            1
# 1           29           30           12           11           12
# 2      -89.57%      -93.22%      -83.33%      -90.91%      -91.49%
# 3  9 out of 11  9 out of 11  9 out of 11  9 out of 11  9 out of 11
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Apr 19  2023  Apr 2  2023 Apr 20  2023 Apr 21  2023 Apr 22  2023  \
# 0            1            2            3            8            8
# ...

# %%
print(df5.shape)
df5.head()
# Out:
# (16, 107)
#    Aug 1  2023 Aug 10  2023 Aug 11  2023 Aug 12  2023 Aug 13  2023  \
# 0            0            1            4            2            0
# 1           10           16           19           19           11
# 2     -100.00%      -93.70%      -78.38%      -89.19%     -100.00%
# 3  9 out of 11  9 out of 11  9 out of 11  9 out of 11  9 out of 11
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Aug 14  2023 Aug 15  2023 Aug 16  2023 Aug 17  2023 Aug 18  2023  \
# 0            2            3            8            6            5
# 1            9           12           16           19           26
# 2      -76.81%      -74.47%      -49.61%      -67.79%      -80.68%
# 3  9 out of 11  9 out of 11  7 out of 11  9 out of 11  9 out of 11
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Aug 19  2023  Aug 2  2023 Aug 20  2023 Aug 21  2023 Aug 22  2023  \
# 0            1            4            2            0            3
# ...

# %%
#colunaextranet
col = '../data/colunaextranet.csv'
col1 = pd.read_csv(col)
pd.set_option('display.max_columns', None)
print(col1.shape)
col1.head()
# Out:
# (16, 1)
#                       Unnamed: 0
# 0                    Room nights
# 1  Room nights (Competitive set)
# 2                   % difference
# 3                        Ranking
# 4                            NaN

# %%
col1 = col1.rename(columns={col1.columns[0]: 'parameters'})
col1.head()
# Out:
#                       parameters
# 0                    Room nights
# 1  Room nights (Competitive set)
# 2                   % difference
# 3                        Ranking
# 4                            NaN

# %%
df1.insert(0, 'parameters', col1['parameters'])
df1.head()
# Out:
#                       parameters  Oct 1  2022  Oct 2  2022  Oct 3  2022  \
# 0                    Room nights            8            6            5
# 1  Room nights (Competitive set)           16            6            7
# 2                   % difference      -50.39%       +0.00%      -31.03%
# 3                        Ranking  7 out of 11  3 out of 11  6 out of 11
# 4                            NaN          NaN          NaN          NaN
#
#    Oct 4  2022  Oct 5  2022  Oct 6  2022  Oct 7  2022  Oct 8  2022  \
# 0            2            5            6           11           12
# 1           12           10           15           28           34
# 2      -82.72%      -50.62%      -60.33%      -60.89%      -64.71%
# 3  8 out of 11  8 out of 11  8 out of 11  8 out of 11  8 out of 11
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Sep 10  2022 Sep 11  2022 Sep 12  2022 Sep 13  2022 Sep 14  2022  \
# ...

# %%
df2.insert(0, 'parameters', col1['parameters'])
df3.insert(0, 'parameters', col1['parameters'])
df4.insert(0, 'parameters', col1['parameters'])
df5.insert(0, 'parameters', col1['parameters'])

# %%
data = pd.concat([df1, df2, df3, df4, df5], axis=1)
print(data.shape)
data.head()
# Out:
# (16, 398)
#                       parameters  Oct 1  2022  Oct 2  2022  Oct 3  2022  \
# 0                    Room nights            8            6            5
# 1  Room nights (Competitive set)           16            6            7
# 2                   % difference      -50.39%       +0.00%      -31.03%
# 3                        Ranking  7 out of 11  3 out of 11  6 out of 11
# 4                            NaN          NaN          NaN          NaN
#
#    Oct 4  2022  Oct 5  2022  Oct 6  2022  Oct 7  2022  Oct 8  2022  \
# 0            2            5            6           11           12
# 1           12           10           15           28           34
# 2      -82.72%      -50.62%      -60.33%      -60.89%      -64.71%
# 3  8 out of 11  8 out of 11  8 out of 11  8 out of 11  8 out of 11
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Sep 10  2022 Sep 11  2022 Sep 12  2022 Sep 13  2022 Sep 14  2022  \
# ...

# %%
duplicated_columns = data.columns[data.columns.duplicated()]

# Keep the first occurrence of each duplicated column
data = data.loc[:, ~data.columns.duplicated()]
data.head()
# Out:
#                       parameters  Oct 1  2022  Oct 2  2022  Oct 3  2022  \
# 0                    Room nights            8            6            5
# 1  Room nights (Competitive set)           16            6            7
# 2                   % difference      -50.39%       +0.00%      -31.03%
# 3                        Ranking  7 out of 11  3 out of 11  6 out of 11
# 4                            NaN          NaN          NaN          NaN
#
#    Oct 4  2022  Oct 5  2022  Oct 6  2022  Oct 7  2022  Oct 8  2022  \
# 0            2            5            6           11           12
# 1           12           10           15           28           34
# 2      -82.72%      -50.62%      -60.33%      -60.89%      -64.71%
# 3  8 out of 11  8 out of 11  8 out of 11  8 out of 11  8 out of 11
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Sep 10  2022 Sep 11  2022 Sep 12  2022 Sep 13  2022 Sep 14  2022  \
# ...

# %%
print(data.dtypes)


#data.columns = pd.to_datetime(data.columns).strftime('%Y %m %d')
#data.head()
# Out:
# parameters      object
# Oct 1  2022     object
# Oct 2  2022     object
# Oct 3  2022     object
# Oct 4  2022     object
#                  ...
# May 28  2023    object
# May 29  2023    object
# May 30  2023    object
# May 31  2023    object
# Sep 1  2023     object
# Length: 366, dtype: object

# %%
data = data.drop("Unnamed: 8", axis=1)

# %%
filtered_columns = [col for col in data.columns if "2022" not in col and "2023" not in col]
unique_filtered_columns = set(filtered_columns)
unique_filtered_columns
# Out:
# {'parameters'}

# %%
data.head()
# Out:
#                       parameters  Oct 1  2022  Oct 2  2022  Oct 3  2022  \
# 0                    Room nights            8            6            5
# 1  Room nights (Competitive set)           16            6            7
# 2                   % difference      -50.39%       +0.00%      -31.03%
# 3                        Ranking  7 out of 11  3 out of 11  6 out of 11
# 4                            NaN          NaN          NaN          NaN
#
#    Oct 4  2022  Oct 5  2022  Oct 6  2022  Oct 7  2022  Oct 8  2022  \
# 0            2            5            6           11           12
# 1           12           10           15           28           34
# 2      -82.72%      -50.62%      -60.33%      -60.89%      -64.71%
# 3  8 out of 11  8 out of 11  8 out of 11  8 out of 11  8 out of 11
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Sep 10  2022 Sep 11  2022 Sep 12  2022 Sep 13  2022 Sep 14  2022  \
# ...

# %%
data.set_index('parameters', inplace=True)
data.head()
# Out:
#                                Oct 1  2022  Oct 2  2022  Oct 3  2022  \
# parameters
# Room nights                              8            6            5
# Room nights (Competitive set)           16            6            7
# % difference                       -50.39%       +0.00%      -31.03%
# Ranking                        7 out of 11  3 out of 11  6 out of 11
# NaN                                    NaN          NaN          NaN
#
#                                Oct 4  2022  Oct 5  2022  Oct 6  2022  \
# parameters
# Room nights                              2            5            6
# Room nights (Competitive set)           12           10           15
# % difference                       -82.72%      -50.62%      -60.33%
# Ranking                        8 out of 11  8 out of 11  8 out of 11
# NaN                                    NaN          NaN          NaN
#
#                                Oct 7  2022  Oct 8  2022 Sep 10  2022  \
# parameters
# ...

# %%
data.columns = pd.to_datetime(data.columns).strftime('%Y %m %d')
data.head()
# Out:
#                                 2022 10 01   2022 10 02   2022 10 03  \
# parameters
# Room nights                              8            6            5
# Room nights (Competitive set)           16            6            7
# % difference                       -50.39%       +0.00%      -31.03%
# Ranking                        7 out of 11  3 out of 11  6 out of 11
# NaN                                    NaN          NaN          NaN
#
#                                 2022 10 04   2022 10 05   2022 10 06  \
# parameters
# Room nights                              2            5            6
# Room nights (Competitive set)           12           10           15
# % difference                       -82.72%      -50.62%      -60.33%
# Ranking                        8 out of 11  8 out of 11  8 out of 11
# NaN                                    NaN          NaN          NaN
#
#                                 2022 10 07   2022 10 08   2022 09 10  \
# parameters
# ...

# %%
data.columns = data.columns.sort_values()
data.head(20)
# Out:
#                                            2022 09 03   2022 09 04  \
# parameters
# Room nights                                         8            6
# Room nights (Competitive set)                      16            6
# % difference                                  -50.39%       +0.00%
# Ranking                                   7 out of 11  3 out of 11
# NaN                                               NaN          NaN
# Revenue (BRL)                                 2876.81      2093.26
# Revenue (BRL) (Competitive set)               6626.22      2344.03
# % difference                                  -56.58%      -10.70%
# Ranking                                   8 out of 11  4 out of 11
# NaN                                               NaN          NaN
# Average daily rate BRL                         359.60       348.88
# Average daily rate BRL (Competitive set)       410.93       390.67
# % difference                                  -12.49%      -10.70%
# ...

# %%
data.dropna(how='all', inplace=True)
data.head(20)
# Out:
#                                            2022 09 03   2022 09 04  \
# parameters
# Room nights                                         8            6
# Room nights (Competitive set)                      16            6
# % difference                                  -50.39%       +0.00%
# Ranking                                   7 out of 11  3 out of 11
# Revenue (BRL)                                 2876.81      2093.26
# Revenue (BRL) (Competitive set)               6626.22      2344.03
# % difference                                  -56.58%      -10.70%
# Ranking                                   8 out of 11  4 out of 11
# Average daily rate BRL                         359.60       348.88
# Average daily rate BRL (Competitive set)       410.93       390.67
# % difference                                  -12.49%      -10.70%
# Ranking                                   6 out of 11  4 out of 11
#
#                                            2022 09 05   2022 09 06  \
# parameters
# ...

# %%
data_copy = data.copy()
print(data_copy.shape)
# Out:
# (12, 364)

# %%
data_copy = data_copy.transpose()
data_copy.head()
# Out:
# parameters Room nights Room nights (Competitive set) % difference  \
# 2022 09 03           8                            16      -50.39%
# 2022 09 04           6                             6       +0.00%
# 2022 09 05           5                             7      -31.03%
# 2022 09 06           2                            12      -82.72%
# 2022 09 07           5                            10      -50.62%
#
# parameters      Ranking Revenue (BRL) Revenue (BRL) (Competitive set)  \
# 2022 09 03  7 out of 11       2876.81                         6626.22
# 2022 09 04  3 out of 11       2093.26                         2344.03
# 2022 09 05  6 out of 11       1712.28                         2890.49
# 2022 09 06  8 out of 11        668.53                         5001.78
# 2022 09 07  8 out of 11       1689.92                         4475.92
#
# parameters % difference      Ranking Average daily rate BRL  \
# 2022 09 03      -56.58%  8 out of 11                 359.60
# ...

# %%
df_extracted = data_copy.iloc[:, [2, 9]]
df_extracted.head()
# Out:
# parameters % difference Average daily rate BRL (Competitive set)
# 2022 09 03      -50.39%                                   410.93
# 2022 09 04       +0.00%                                   390.67
# 2022 09 05      -31.03%                                   398.69
# 2022 09 06      -82.72%                                   432.25
# 2022 09 07      -50.62%                                   442.07

# %%
# Convert the index to datetime
df_extracted.index = pd.to_datetime(df_extracted.index)

# Create a new column 'day_of_week' based on the day of the week from the index
df_extracted['day_of_week'] = df_extracted.index.dayofweek.map({0: 2, 1: 3, 2: 3, 3: 4, 4: 5, 5: 5, 6: 1})

# Print the updated DataFrame
df_extracted.head()
# Out:
# parameters % difference Average daily rate BRL (Competitive set)  day_of_week
# 2022-09-03      -50.39%                                   410.93            5
# 2022-09-04       +0.00%                                   390.67            1
# 2022-09-05      -31.03%                                   398.69            2
# 2022-09-06      -82.72%                                   432.25            3
# 2022-09-07      -50.62%                                   442.07            3

# %%
df_filtered = df_extracted[~df_extracted.index.strftime('%Y-%m').str.startswith('2023-09')]

# %%
ocupacao_mapping = {
    '2022-09-%': 69.22,
    '2022-10-%': 64.85,
    '2022-11-%': 71.92,
    '2022-12-%': 54.66,
    '2023-01-%': 50.82,
    '2023-02-%': 56.62,
    '2023-03-%': 77.19,
    '2023-04-%': 64.68,
    '2023-05-%': 67.32,
    '2023-06-%': 68.72,
    '2023-07-%': 59.51,
    '2023-08-%': 62.78
}

# Create a new column 'ocupação_competitors' based on the index dates
df_filtered['occup_competitors'] = df_filtered.index.strftime('%Y-%m-%d').map(ocupacao_mapping)
df_filtered.head()
# Out:
# parameters % difference Average daily rate BRL (Competitive set)  day_of_week  \
# 2022-09-03      -50.39%                                   410.93            5
# 2022-09-04       +0.00%                                   390.67            1
# 2022-09-05      -31.03%                                   398.69            2
# 2022-09-06      -82.72%                                   432.25            3
# 2022-09-07      -50.62%                                   442.07            3
#
# parameters  occup_competitors
# 2022-09-03                NaN
# 2022-09-04                NaN
# 2022-09-05                NaN
# 2022-09-06                NaN
# 2022-09-07                NaN

# %%
ocupacao_mapping = {
    '2022-09': 69.22,
    '2022-10': 64.85,
    '2022-11': 71.92,
    '2022-12': 54.66,
    '2023-01': 50.82,
    '2023-02': 56.62,
    '2023-03': 77.19,
    '2023-04': 64.68,
    '2023-05': 67.32,
    '2023-06': 68.72,
    '2023-07': 59.51,
    '2023-08': 62.78
}

# Extract the year and month from the index and apply the values directly
df_filtered['occup_competitors'] = df_filtered.index.strftime('%Y-%m').map(ocupacao_mapping)
df_filtered.head()
# Out:
# parameters % difference Average daily rate BRL (Competitive set)  day_of_week  \
# 2022-09-03      -50.39%                                   410.93            5
# 2022-09-04       +0.00%                                   390.67            1
# 2022-09-05      -31.03%                                   398.69            2
# 2022-09-06      -82.72%                                   432.25            3
# 2022-09-07      -50.62%                                   442.07            3
#
# parameters  occup_competitors
# 2022-09-03              69.22
# 2022-09-04              69.22
# 2022-09-05              69.22
# 2022-09-06              69.22
# 2022-09-07              69.22

# %%
imat_mapping = {
    '2022-09': 95.9,
    '2022-10': 93.0,
    '2022-11': 101.1,
    '2022-12': 100.9,
    '2023-01': 98.0,
    '2023-02': 94.4,
    '2023-03': 109.6,
    '2023-04': 102.0,
    '2023-05': 100.4,
    '2023-06': 108.0,
    '2023-07': 100.33,
    '2023-08': 100.33
}

# Extract the year and month from the index and apply the values directly
df_filtered['imat_sp'] = df_filtered.index.strftime('%Y-%m').map(imat_mapping)
df_filtered.head()
# Out:
# parameters % difference Average daily rate BRL (Competitive set)  day_of_week  \
# 2022-09-03      -50.39%                                   410.93            5
# 2022-09-04       +0.00%                                   390.67            1
# 2022-09-05      -31.03%                                   398.69            2
# 2022-09-06      -82.72%                                   432.25            3
# 2022-09-07      -50.62%                                   442.07            3
#
# parameters  occup_competitors  imat_sp
# 2022-09-03              69.22     95.9
# 2022-09-04              69.22     95.9
# 2022-09-05              69.22     95.9
# 2022-09-06              69.22     95.9
# 2022-09-07              69.22     95.9

# %%
df_filtered['events'] = np.where(df_filtered.index == '2022-09-08', 1, 0)
df_filtered.head(10)
# Out:
# parameters % difference Average daily rate BRL (Competitive set)  day_of_week  \
# 2022-09-03      -50.39%                                   410.93            5
# 2022-09-04       +0.00%                                   390.67            1
# 2022-09-05      -31.03%                                   398.69            2
# 2022-09-06      -82.72%                                   432.25            3
# 2022-09-07      -50.62%                                   442.07            3
# 2022-09-08      -60.33%                                   441.27            4
# 2022-09-09      -60.89%                                   406.09            5
# 2022-09-10      -64.71%                                   408.77            5
# 2022-09-11      -80.49%                                   422.12            1
# 2022-09-12      -83.16%                                   386.19            2
#
# parameters  occup_competitors  imat_sp  events
# 2022-09-03              69.22     95.9       0
# ...

# %%
df_filtered.loc[(df_filtered.index >= '2023-03-11') & (df_filtered.index <= '2023-03-19'), 'events'] = 1
df_filtered.loc[(df_filtered.index >= '2023-03-23') & (df_filtered.index <= '2023-03-26'), 'events'] = 4
df_filtered.loc[(df_filtered.index >= '2022-11-16') & (df_filtered.index <= '2022-11-20'), 'events'] = 1
df_filtered.loc[(df_filtered.index >= '2023-05-25') & (df_filtered.index <= '2023-05-28'), 'events'] = 1
df_filtered.loc[(df_filtered.index >= '2022-11-11') & (df_filtered.index <= '2022-11-13'), 'events'] = 2
df_filtered.loc[df_filtered.index == '2022-09-08', 'events'] = 1
df_filtered.loc[df_filtered.index == '2022-09-24', 'events'] = 1
df_filtered.loc[df_filtered.index == '2023-03-10', 'events'] = 3
df_filtered.loc[df_filtered.index == '2023-03-11', 'events'] = 3
df_filtered.loc[df_filtered.index == '2023-03-13', 'events'] = 3
df_filtered.loc[df_filtered.index == '2023-03-14', 'events'] = 3
df_filtered.loc[df_filtered.index == '2023-03-17', 'events'] = 3
df_filtered.loc[df_filtered.index == '2023-03-18', 'events'] = 3
df_filtered.loc[df_filtered.index == '2022-11-05', 'events'] = 2
df_filtered.loc[df_filtered.index == '2022-12-06', 'events'] = 3
df_filtered.loc[df_filtered.index == '2022-12-13', 'events'] = 3
df_filtered.loc[df_filtered.index == '2022-12-14', 'events'] = 3
df_filtered.loc[df_filtered.index == '2023-01-18', 'events'] = 1
df_filtered.loc[df_filtered.index == '2023-02-28', 'events'] = 1
df_filtered.loc[df_filtered.index == '2023-03-07', 'events'] = 1
df_filtered.loc[df_filtered.index == '2023-04-21', 'events'] = 1
df_filtered.loc[df_filtered.index == '2023-04-22', 'events'] = 1
df_filtered.loc[df_filtered.index == '2023-04-24', 'events'] = 2
df_filtered.loc[df_filtered.index == '2023-06-03', 'events'] = 1
df_filtered.loc[(df_filtered.index >= '2023-06-04') & (df_filtered.index <= '2023-06-11'), 'events'] = 2

# %%
df_filtered.head()
# Out:
# parameters % difference Average daily rate BRL (Competitive set)  day_of_week  \
# 2022-09-03      -50.39%                                   410.93            5
# 2022-09-04       +0.00%                                   390.67            1
# 2022-09-05      -31.03%                                   398.69            2
# 2022-09-06      -82.72%                                   432.25            3
# 2022-09-07      -50.62%                                   442.07            3
#
# parameters  occup_competitors  imat_sp  events
# 2022-09-03              69.22     95.9       0
# 2022-09-04              69.22     95.9       0
# 2022-09-05              69.22     95.9       0
# 2022-09-06              69.22     95.9       0
# 2022-09-07              69.22     95.9       0

# %%
values = df_filtered.loc[['2023-03-26', '2022-11-16', '2022-11-17', '2022-11-18', '2022-11-19', '2022-11-20', '2023-05-25', '2023-05-26', '2023-05-27', '2023-05-28', '2022-11-11', '2022-11-12', '2023-04-24'], 'events']
print(values)
# Out:
# 2023-03-26    4
# 2022-11-16    1
# 2022-11-17    1
# 2022-11-18    1
# 2022-11-19    1
# 2022-11-20    1
# 2023-05-25    1
# 2023-05-26    1
# 2023-05-27    1
# 2023-05-28    1
# 2022-11-11    2
# 2022-11-12    2
# 2023-04-24    2
# Name: events, dtype: int32

# %%
last_row = df_filtered.tail(1)
first_row = df_filtered.head(1)
print(last_row)
print(first_row)
# Out:
# parameters % difference Average daily rate BRL (Competitive set)  day_of_week  \
# 2023-08-31      -54.29%                                   488.34            4
#
# parameters  occup_competitors  imat_sp  events
# 2023-08-31              62.78   100.33       0
# parameters % difference Average daily rate BRL (Competitive set)  day_of_week  \
# 2022-09-03      -50.39%                                   410.93            5
#
# parameters  occup_competitors  imat_sp  events
# 2022-09-03              69.22     95.9       0

# %%
print(df_filtered.shape)
# Out:
# (363, 6)

# %%
df_filtered.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 363 entries, 2022-09-03 to 2023-08-31
# Data columns (total 6 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   % difference                              363 non-null    object
#  1   Average daily rate BRL (Competitive set)  363 non-null    object
#  2   day_of_week                               363 non-null    int32
#  3   occup_competitors                         363 non-null    float64
#  4   imat_sp                                   363 non-null    float64
#  5   events                                    363 non-null    int32
# dtypes: float64(2), int32(2), object(2)
# memory usage: 64.5 KB

# %%
df_filtered["occup_competitors"] = df_filtered["occup_competitors"].astype(float) / 100

# %%
df_filtered["imat_sp"] = df_filtered["imat_sp"].astype(float) / 100

# %%
df_filtered.head()
# Out:
# parameters % difference Average daily rate BRL (Competitive set)  day_of_week  \
# 2022-09-03      -50.39%                                   410.93            5
# 2022-09-04       +0.00%                                   390.67            1
# 2022-09-05      -31.03%                                   398.69            2
# 2022-09-06      -82.72%                                   432.25            3
# 2022-09-07      -50.62%                                   442.07            3
#
# parameters  occup_competitors  imat_sp  events
# 2022-09-03             0.6922    0.959       0
# 2022-09-04             0.6922    0.959       0
# 2022-09-05             0.6922    0.959       0
# 2022-09-06             0.6922    0.959       0
# 2022-09-07             0.6922    0.959       0

# %%
df_filtered.rename(columns={"Average daily rate BRL (Competitive set)": "avg_rate_compt"}, inplace=True)
df_filtered.head()
# Out:
# parameters % difference avg_rate_compt  day_of_week  occup_competitors  \
# 2022-09-03      -50.39%         410.93            5             0.6922
# 2022-09-04       +0.00%         390.67            1             0.6922
# 2022-09-05      -31.03%         398.69            2             0.6922
# 2022-09-06      -82.72%         432.25            3             0.6922
# 2022-09-07      -50.62%         442.07            3             0.6922
#
# parameters  imat_sp  events
# 2022-09-03    0.959       0
# 2022-09-04    0.959       0
# 2022-09-05    0.959       0
# 2022-09-06    0.959       0
# 2022-09-07    0.959       0

# %%
df_filtered.rename(columns={"% difference": "sales_rate_comparison"}, inplace=True)
df_filtered.rename(columns={"day_of_week": "weekday_sazonality_guh"}, inplace=True)
df_filtered.rename(columns={"events": "event_sazonality_guh"}, inplace=True)

# %%
df_filtered.head()
# Out:
# parameters sales_rate_comparison avg_rate_compt  weekday_sazonality_guh  \
# 2022-09-03               -50.39%         410.93                       5
# 2022-09-04                +0.00%         390.67                       1
# 2022-09-05               -31.03%         398.69                       2
# 2022-09-06               -82.72%         432.25                       3
# 2022-09-07               -50.62%         442.07                       3
#
# parameters  occup_competitors  imat_sp  event_sazonality_guh
# 2022-09-03             0.6922    0.959                     0
# 2022-09-04             0.6922    0.959                     0
# 2022-09-05             0.6922    0.959                     0
# 2022-09-06             0.6922    0.959                     0
# 2022-09-07             0.6922    0.959                     0

# %%
unique_values = df_filtered["event_sazonality_guh"].unique()
print(unique_values)
# Out:
# [0 1 2 3 4]

# %%
df_filtered.head()
# Out:
# parameters sales_rate_comparison avg_rate_compt  weekday_sazonality_guh  \
# 2022-09-03               -50.39%         410.93                       5
# 2022-09-04                +0.00%         390.67                       1
# 2022-09-05               -31.03%         398.69                       2
# 2022-09-06               -82.72%         432.25                       3
# 2022-09-07               -50.62%         442.07                       3
#
# parameters  occup_competitors  imat_sp  event_sazonality_guh
# 2022-09-03             0.6922    0.959                     0
# 2022-09-04             0.6922    0.959                     0
# 2022-09-05             0.6922    0.959                     0
# 2022-09-06             0.6922    0.959                     0
# 2022-09-07             0.6922    0.959                     0

# %%
df_market = df_filtered.copy()

# %%
df_market.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 363 entries, 2022-09-03 to 2023-08-31
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sales_rate_comparison   363 non-null    object
#  1   avg_rate_compt          363 non-null    object
#  2   weekday_sazonality_guh  363 non-null    int32
#  3   occup_competitors       363 non-null    float64
#  4   imat_sp                 363 non-null    float64
#  5   event_sazonality_guh    363 non-null    int32
# dtypes: float64(2), int32(2), object(2)
# memory usage: 64.5 KB

# %%
df_filtered['avg_rate_compt'] = df_filtered['avg_rate_compt'].astype(float)
df_filtered['weekday_sazonality_guh'] = df_filtered['weekday_sazonality_guh'].astype(float)
df_filtered['event_sazonality_guh'] = df_filtered['event_sazonality_guh'].astype(float)

# %%
df_market.index.name = ''

# %%
df_market.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 363 entries, 2022-09-03 to 2023-08-31
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sales_rate_comparison   363 non-null    object
#  1   avg_rate_compt          363 non-null    object
#  2   weekday_sazonality_guh  363 non-null    int32
#  3   occup_competitors       363 non-null    float64
#  4   imat_sp                 363 non-null    float64
#  5   event_sazonality_guh    363 non-null    int32
# dtypes: float64(2), int32(2), object(2)
# memory usage: 64.5 KB

# %%
df_market.to_csv('../data/market_info.csv', index=True)

# %%
markets = '../data/market_info.csv'
market = pd.read_csv(markets)


guh = pd.read_csv('../data/guh_data.csv', delimiter=';')

# %%
print(market.shape)
market.head()
# Out:
# (363, 7)
#    Unnamed: 0 sales_rate_comparison  avg_rate_compt  weekday_sazonality_guh  \
# 0  2022-09-03               -50.39%          410.93                       5
# 1  2022-09-04                +0.00%          390.67                       1
# 2  2022-09-05               -31.03%          398.69                       2
# 3  2022-09-06               -82.72%          432.25                       3
# 4  2022-09-07               -50.62%          442.07                       3
#
#    occup_competitors  imat_sp  event_sazonality_guh
# 0             0.6922    0.959                     0
# 1             0.6922    0.959                     0
# 2             0.6922    0.959                     0
# 3             0.6922    0.959                     0
# 4             0.6922    0.959                     0

# %%
print(guh.shape)
guh.head()
# Out:
# (363, 4)
#    Unnamed: 0 avg_rate_guh  sold_rooms_guh accu_rate_guh
# 0  2022-09-03       346,93              13        100,00
# 1  2022-09-04       263,58               9         69,23
# 2  2022-09-05       353,13               7         53,85
# 3  2022-09-06       283,95               6         46,15
# 4  2022-09-07       334,38               9         69,23

# %%
data_ml = pd.concat([market, guh], axis=1)
print
data_ml.head()
# Out:
#    Unnamed: 0 sales_rate_comparison  avg_rate_compt  weekday_sazonality_guh  \
# 0  2022-09-03               -50.39%          410.93                       5
# 1  2022-09-04                +0.00%          390.67                       1
# 2  2022-09-05               -31.03%          398.69                       2
# 3  2022-09-06               -82.72%          432.25                       3
# 4  2022-09-07               -50.62%          442.07                       3
#
#    occup_competitors  imat_sp  event_sazonality_guh  Unnamed: 0 avg_rate_guh  \
# 0             0.6922    0.959                     0  2022-09-03       346,93
# 1             0.6922    0.959                     0  2022-09-04       263,58
# 2             0.6922    0.959                     0  2022-09-05       353,13
# 3             0.6922    0.959                     0  2022-09-06       283,95
# 4             0.6922    0.959                     0  2022-09-07       334,38
#
#    sold_rooms_guh accu_rate_guh
# ...

# %%
duplicated_columns = data_ml.columns[data_ml.columns.duplicated()]

# Keep the first occurrence of each duplicated column
data_ml = data_ml.loc[:, ~data_ml.columns.duplicated()]
data_ml.head()
# Out:
#    Unnamed: 0 sales_rate_comparison  avg_rate_compt  weekday_sazonality_guh  \
# 0  2022-09-03               -50.39%          410.93                       5
# 1  2022-09-04                +0.00%          390.67                       1
# 2  2022-09-05               -31.03%          398.69                       2
# 3  2022-09-06               -82.72%          432.25                       3
# 4  2022-09-07               -50.62%          442.07                       3
#
#    occup_competitors  imat_sp  event_sazonality_guh avg_rate_guh  \
# 0             0.6922    0.959                     0       346,93
# 1             0.6922    0.959                     0       263,58
# 2             0.6922    0.959                     0       353,13
# 3             0.6922    0.959                     0       283,95
# 4             0.6922    0.959                     0       334,38
#
#    sold_rooms_guh accu_rate_guh
# 0              13        100,00
# 1               9         69,23
# ...

# %%
data_ml.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 363 entries, 0 to 362
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              363 non-null    object
#  1   sales_rate_comparison   363 non-null    object
#  2   avg_rate_compt          363 non-null    float64
#  3   weekday_sazonality_guh  363 non-null    int64
#  4   occup_competitors       363 non-null    float64
#  5   imat_sp                 363 non-null    float64
#  6   event_sazonality_guh    363 non-null    int64
#  7   avg_rate_guh            363 non-null    object
#  8   sold_rooms_guh          363 non-null    int64
#  9   accu_rate_guh           363 non-null    object
# dtypes: float64(3), int64(3), object(4)
# memory usage: 108.0 KB

# %%
data_ml.rename(columns={"Unnamed: 0": "date"}, inplace=True)

# %%
data_ml.rename(columns={"accu_rate_guh": "occup_rate_guh"}, inplace=True)

# %%
data_ml['date'] = pd.to_datetime(data_ml['date'])

# %%
avg_rate_guh_column = data_ml.pop('avg_rate_guh')
data_ml['avg_rate_guh'] = avg_rate_guh_column

# %%
data_ml.head()
# Out:
#         date sales_rate_comparison  avg_rate_compt  weekday_sazonality_guh  \
# 0 2022-09-03               -50.39%          410.93                       5
# 1 2022-09-04                +0.00%          390.67                       1
# 2 2022-09-05               -31.03%          398.69                       2
# 3 2022-09-06               -82.72%          432.25                       3
# 4 2022-09-07               -50.62%          442.07                       3
#
#    occup_competitors  imat_sp  event_sazonality_guh  sold_rooms_guh  \
# 0             0.6922    0.959                     0              13
# 1             0.6922    0.959                     0               9
# 2             0.6922    0.959                     0               7
# 3             0.6922    0.959                     0               6
# 4             0.6922    0.959                     0               9
#
#   occup_rate_guh avg_rate_guh
# 0         100,00       346,93
# 1          69,23       263,58
# ...

# %%
data_ml['occup_rate_guh'] = data_ml['occup_rate_guh'].str.replace(',', '.').astype(float)

# %%
data_ml['avg_rate_guh'] = data_ml['avg_rate_guh'].str.replace(',', '.').astype(float)

# %%
data_ml["occup_rate_guh"] = data_ml["occup_rate_guh"].astype(float) / 100

# %%
data_ml.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 363 entries, 0 to 362
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    363 non-null    datetime64[ns]
#  1   sales_rate_comparison   363 non-null    object
#  2   avg_rate_compt          363 non-null    float64
#  3   weekday_sazonality_guh  363 non-null    int64
#  4   occup_competitors       363 non-null    float64
#  5   imat_sp                 363 non-null    float64
#  6   event_sazonality_guh    363 non-null    int64
#  7   sold_rooms_guh          363 non-null    int64
#  8   occup_rate_guh          363 non-null    float64
#  9   avg_rate_guh            363 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(3), object(1)
# memory usage: 48.4 KB

# %%
data_ml["sold_rooms_guh"] = data_ml["sold_rooms_guh"].astype(float)

# %%
data_ml.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 363 entries, 0 to 362
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    363 non-null    datetime64[ns]
#  1   sales_rate_comparison   363 non-null    object
#  2   avg_rate_compt          363 non-null    float64
#  3   weekday_sazonality_guh  363 non-null    int64
#  4   occup_competitors       363 non-null    float64
#  5   imat_sp                 363 non-null    float64
#  6   event_sazonality_guh    363 non-null    int64
#  7   sold_rooms_guh          363 non-null    float64
#  8   occup_rate_guh          363 non-null    float64
#  9   avg_rate_guh            363 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(1)
# memory usage: 48.4 KB

# %%
data_ml.head()
# Out:
#         date sales_rate_comparison  avg_rate_compt  weekday_sazonality_guh  \
# 0 2022-09-03               -50.39%          410.93                       5
# 1 2022-09-04                +0.00%          390.67                       1
# 2 2022-09-05               -31.03%          398.69                       2
# 3 2022-09-06               -82.72%          432.25                       3
# 4 2022-09-07               -50.62%          442.07                       3
#
#    occup_competitors  imat_sp  event_sazonality_guh  sold_rooms_guh  \
# 0             0.6922    0.959                     0            13.0
# 1             0.6922    0.959                     0             9.0
# 2             0.6922    0.959                     0             7.0
# 3             0.6922    0.959                     0             6.0
# 4             0.6922    0.959                     0             9.0
#
#    occup_rate_guh  avg_rate_guh
# 0          1.0000        346.93
# 1          0.6923        263.58
# ...

# %%
data_ml.to_csv('../data/data_ml.csv', index=False)
teste = pd.read_csv('../data/data_ml.csv')
teste.head()
# Out:
#          date sales_rate_comparison  avg_rate_compt  weekday_sazonality_guh  \
# 0  2022-09-03               -50.39%          410.93                       5
# 1  2022-09-04                +0.00%          390.67                       1
# 2  2022-09-05               -31.03%          398.69                       2
# 3  2022-09-06               -82.72%          432.25                       3
# 4  2022-09-07               -50.62%          442.07                       3
#
#    occup_competitors  imat_sp  event_sazonality_guh  sold_rooms_guh  \
# 0             0.6922    0.959                     0            13.0
# 1             0.6922    0.959                     0             9.0
# 2             0.6922    0.959                     0             7.0
# 3             0.6922    0.959                     0             6.0
# 4             0.6922    0.959                     0             9.0
#
#    occup_rate_guh  avg_rate_guh
# 0          1.0000        346.93
# 1          0.6923        263.58
# ...

# %%
data_ml_final = data_ml['holidays_sazonality_guh'] = np.where(data_ml.index == '2022-09-07', -1, 0)
data_ml_final = pd.DataFrame(data_ml)

# %%
data_ml_final.head()
# Out:
#         date sales_rate_comparison  avg_rate_compt  weekday_sazonality_guh  \
# 0 2022-09-03               -50.39%          410.93                       5
# 1 2022-09-04                +0.00%          390.67                       1
# 2 2022-09-05               -31.03%          398.69                       2
# 3 2022-09-06               -82.72%          432.25                       3
# 4 2022-09-07               -50.62%          442.07                       3
#
#    occup_competitors  imat_sp  event_sazonality_guh  sold_rooms_guh  \
# 0             0.6922    0.959                     0            13.0
# 1             0.6922    0.959                     0             9.0
# 2             0.6922    0.959                     0             7.0
# 3             0.6922    0.959                     0             6.0
# 4             0.6922    0.959                     0             9.0
#
#    occup_rate_guh  avg_rate_guh  holidays_sazonality_guh
# ...

# %%
data_ml_final.loc[(data_ml_final['date'] >= '2022-11-11') & (data_ml_final['date'] <= '2022-11-14'), 'holidays_sazonality_guh'] = 2
data_ml_final.loc[(data_ml_final['date'] >= '2022-12-23') & (data_ml_final['date'] <= '2023-01-02'), 'holidays_sazonality_guh'] = -1
data_ml_final.loc[(data_ml_final['date'] >= '2023-04-06') & (data_ml_final['date'] <= '2023-04-08'), 'holidays_sazonality_guh'] = -1
data_ml_final.loc[(data_ml_final['date'] >= '2023-04-20') & (data_ml_final['date'] <= '2023-04-22'), 'holidays_sazonality_guh'] = 2
data_ml_final.loc[(data_ml_final['date'] >= '2023-02-17') & (data_ml_final['date'] <= '2023-02-22'), 'holidays_sazonality_guh'] = 1
data_ml_final.loc[(data_ml_final['date'] >= '2023-05-28') & (data_ml_final['date'] <= '2023-05-30'), 'holidays_sazonality_guh'] = 2
data_ml_final.loc[(data_ml_final['date'] >= '2023-06-07') & (data_ml_final['date'] <= '2023-06-10'), 'holidays_sazonality_guh'] = 2

data_ml_final.loc[data_ml_final['date'] == '2022-09-06', 'holidays_sazonality_guh'] = -1
data_ml_final.loc[data_ml_final['date'] == '2022-09-07', 'holidays_sazonality_guh'] = -1
data_ml_final.loc[data_ml_final['date'] == '2022-10-11', 'holidays_sazonality_guh'] = -1
data_ml_final.loc[data_ml_final['date'] == '2022-10-12', 'holidays_sazonality_guh'] = -1
data_ml_final.loc[data_ml_final['date'] == '2022-11-01', 'holidays_sazonality_guh'] = -1
data_ml_final.loc[data_ml_final['date'] == '2022-11-02', 'holidays_sazonality_guh'] = -1
data_ml_final.loc[data_ml_final['date'] == '2023-01-24', 'holidays_sazonality_guh'] = -1
data_ml_final.loc[data_ml_final['date'] == '2023-01-25', 'holidays_sazonality_guh'] = -1
data_ml_final.loc[data_ml_final['date'] == '2023-07-07', 'holidays_sazonality_guh'] = 2
data_ml_final.loc[data_ml_final['date'] == '2023-07-08', 'holidays_sazonality_guh'] = 2
data_ml_final.loc[data_ml_final['date'] == '2023-05-06', 'holidays_sazonality_guh'] = 2
data_ml_final.loc[data_ml_final['date'] == '2023-05-07', 'holidays_sazonality_guh'] = -1

# %%
unique_values = data_ml_final["holidays_sazonality_guh"].unique()
print(unique_values)
# Out:
# [ 0 -1  2  1]

# %%
data_ml_final = data_ml['vacation_sazonality'] = np.where(data_ml.index == '2022-09-07', 1, 1)
data_ml_final = pd.DataFrame(data_ml)

# %%
data_ml_final.loc[(data_ml_final['date'] >= '2022-12-16') & (data_ml_final['date'] <= '2023-02-22'), 'vacation_sazonality'] = -1
data_ml_final.loc[(data_ml_final['date'] >= '2023-07-01') & (data_ml_final['date'] <= '2023-07-31'), 'vacation_sazonality'] = -1

# %%
unique_values = data_ml_final["vacation_sazonality"].unique()
print(unique_values)
# Out:
# [ 1 -1]

# %%
avg_rate_guh_column = data_ml.pop('avg_rate_guh')
data_ml_final['avg_rate_guh'] = avg_rate_guh_column

# %%
data_ml_final.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 363 entries, 0 to 362
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     363 non-null    datetime64[ns]
#  1   sales_rate_comparison    363 non-null    object
#  2   avg_rate_compt           363 non-null    float64
#  3   weekday_sazonality_guh   363 non-null    int64
#  4   occup_competitors        363 non-null    float64
#  5   imat_sp                  363 non-null    float64
#  6   event_sazonality_guh     363 non-null    int64
#  7   sold_rooms_guh           363 non-null    float64
#  8   occup_rate_guh           363 non-null    float64
#  9   avg_rate_guh             363 non-null    float64
#  10  holidays_sazonality_guh  363 non-null    int32
#  11  vacation_sazonality      363 non-null    int32
# dtypes: datetime64[ns](1), float64(6), int32(2), int64(2), object(1)
# memory usage: 51.2 KB

# %%
data_ml_final['sales_rate_comparison'] = data_ml_final['sales_rate_comparison'].str.replace('%', '').astype(float) / 100

# %%
data_ml_final.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 363 entries, 0 to 362
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     363 non-null    datetime64[ns]
#  1   sales_rate_comparison    363 non-null    float64
#  2   avg_rate_compt           363 non-null    float64
#  3   weekday_sazonality_guh   363 non-null    int64
#  4   occup_competitors        363 non-null    float64
#  5   imat_sp                  363 non-null    float64
#  6   event_sazonality_guh     363 non-null    int64
#  7   sold_rooms_guh           363 non-null    float64
#  8   occup_rate_guh           363 non-null    float64
#  9   avg_rate_guh             363 non-null    float64
#  10  holidays_sazonality_guh  363 non-null    int32
#  11  vacation_sazonality      363 non-null    int32
# dtypes: datetime64[ns](1), float64(7), int32(2), int64(2)
# memory usage: 31.3 KB

# %%
data_ml_final['weekday_sazonality_guh'] = data_ml_final['weekday_sazonality_guh'].astype(float)
data_ml_final['event_sazonality_guh'] = data_ml_final['event_sazonality_guh'].astype(float)
data_ml_final['holidays_sazonality_guh'] = data_ml_final['holidays_sazonality_guh'].astype(float)
data_ml_final['vacation_sazonality'] = data_ml_final['vacation_sazonality'].astype(float)
data_ml_final.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 363 entries, 0 to 362
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     363 non-null    datetime64[ns]
#  1   sales_rate_comparison    363 non-null    float64
#  2   avg_rate_compt           363 non-null    float64
#  3   weekday_sazonality_guh   363 non-null    float64
#  4   occup_competitors        363 non-null    float64
#  5   imat_sp                  363 non-null    float64
#  6   event_sazonality_guh     363 non-null    float64
#  7   sold_rooms_guh           363 non-null    float64
#  8   occup_rate_guh           363 non-null    float64
#  9   avg_rate_guh             363 non-null    float64
#  10  holidays_sazonality_guh  363 non-null    float64
#  11  vacation_sazonality      363 non-null    float64
# dtypes: datetime64[ns](1), float64(11)
# memory usage: 34.2 KB

# %%
data_ml_final.to_csv('../data/data_ml.csv', index=False)

# %%
data_ml_final.tail()
# Out:
#           date  sales_rate_comparison  avg_rate_compt  weekday_sazonality_guh  \
# 358 2023-08-27                -0.7888          441.60                     1.0
# 359 2023-08-28                -0.6694          435.63                     2.0
# 360 2023-08-29                -0.5402          462.75                     3.0
# 361 2023-08-30                -0.6768          482.80                     3.0
# 362 2023-08-31                -0.5429          488.34                     4.0
#
#      occup_competitors  imat_sp  event_sazonality_guh  sold_rooms_guh  \
# 358             0.6278   1.0033                   0.0             5.0
# 359             0.6278   1.0033                   0.0             8.0
# 360             0.6278   1.0033                   0.0            12.0
# 361             0.6278   1.0033                   0.0            12.0
# 362             0.6278   1.0033                   0.0            13.0
#
#      occup_rate_guh  avg_rate_guh  holidays_sazonality_guh  \
# ...
